# %% [markdown]
# ## Final Assignment: Problem Formulation
#
# For this project you work with real data from Airbnb with the goal is to explore the data and build a tool to get an estimate for a new listening in Stockholm. Imagine you have an apartment in Stockholm and would like to rent it out via Airbnb. What price should you set? Minimum nights per stay? What amenities do you need to stick out against the hard competition in Stockholm? What are important keywords in your title and description? These and many other questions are important to answer. With the provided data you can find an answer to the question.
#
#
#
# The tool you create, should take an address, number of rooms and different amenities (dryer, oven, smoke alarm) as an input and provide the user with an estimate rental price per night. Additionally provide information how you would stick out against the competition.
# Here the functionality of the tool is most important rather than a perfect designed user interface.

# %% [markdown]
# ## Loading Libraries and Dataset

# %%
import pandas as pd  # For data manipulation and reading CSV files
import numpy as np   # For numerical operations
import matplotlib.pyplot as plt # For plotting graphs
import seaborn as sns # For enhanced data visualization
import io
import warnings
warnings.filterwarnings('ignore') # ignore pandas FutureWarnings


# Set some display options for pandas DataFrames for better readability
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', 100)     
pd.set_option('display.float_format', lambda x: '%.3f' % x) 

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
try:
    file_path = 'listings.csv' 

    # Load the dataset
    df_raw = pd.read_csv(file_path)
    df = df_raw.copy()

    print(f"Dataset loaded successfully from: {file_path}")
    print(f"Dataset shape (rows, columns): {df.shape}")

except FileNotFoundError:
    print(f"Error: The file was not found at the specified path: {file_path}")
    print("Please ensure the file path is correct.")
except Exception as e:
    print(f"An error occurred during data loading: {e}")
# Out:
# Dataset loaded successfully from: listings.csv
# Dataset shape (rows, columns): (5223, 75)

# %% [markdown]
# ## Initial Data Exploration

# %%
if 'df' in locals():
    print("\n--- Initial Data Exploration ---")

    # 1. Display the first few rows
    print("\n1. First 5 rows of the dataset:")
    display(df.head()) 

    # 2. Display concise summary of the DataFrame
    print("\n2. DataFrame Info (Column Types and Non-Null Counts):")
    df.info() 

    # 3. Display basic descriptive statistics for numerical columns
    print("\n3. Descriptive Statistics for Numerical Columns:")
    display(df.describe())

    # 4. Display basic descriptive statistics for object (text/categorical) columns
    print("\n4. Descriptive Statistics for Object/Categorical Columns:")
    display(df.describe(include='object'))

    # 5. Check for missing values (showing percentage)
    print("\n5. Percentage of Missing Values per Column (sorted):")
    missing_percentage = (df.isnull().sum() / len(df) * 100).sort_values(ascending=False)
    # Filter to show only columns with missing values
    missing_percentage = missing_percentage[missing_percentage > 0]
    if not missing_percentage.empty:
      print(missing_percentage)
    else:
      print("No missing values found.")


    # 6. Check the number of unique values in each column
    print("\n6. Number of Unique Values per Column:")
    unique_counts = df.nunique().sort_values()
    print(unique_counts)

    # 7. Quick check on the target variable 'price' if it exists
    if 'price' in df.columns:
        print("\n7. Initial check on the 'price' column:")
        print(f"   Data type: {df['price'].dtype}")
        # Show some example values if it's an object type (likely needs cleaning)
        if df['price'].dtype == 'object':
            print(f"   Example values: {df['price'].dropna().unique()[:10]}") 
        else:
             # If already numeric, show range
             print(f"   Min price: {df['price'].min()}, Max price: {df['price'].max()}")
    else:
        print("\nWarning: 'price' column not found in the dataset.")

else:
    print("\nSkipping Initial EDA because the DataFrame 'df' was not loaded.")
# Out:
# --- Initial Data Exploration ---
#
# 1. First 5 rows of the dataset:
#        id                          listing_url       scrape_id last_scraped  \
# 0  164448  https://www.airbnb.com/rooms/164448  20241230011645   2024-12-30
# 1  220851  https://www.airbnb.com/rooms/220851  20241230011645   2024-12-30
# 2  238411  https://www.airbnb.com/rooms/238411  20241230011645   2024-12-30
# 3  242188  https://www.airbnb.com/rooms/242188  20241230011645   2024-12-30
# 4  273906  https://www.airbnb.com/rooms/273906  20241230011645   2024-12-30
#
#         source                                         name  \
# 0  city scrape  Double room in central Stockholm with Wi-Fi
# 1  city scrape                      One room in appartement
# 2  city scrape          Cozy apartment in central Stockholm
# 3  city scrape  Single room in central Stockholm with Wi-Fi
# 4  city scrape               Penthouse in central Stockholm
#
#                                          description  \
# 0  I am renting out a nice double room on the top...
# 1                                           Welcome!
# 2                                                NaN
# 3  I am renting out a nice single room on the top...
# 4                                                NaN
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Many restaurangs wery close and walkingdistanc...
# 2  Restaurants, cafés, museums, art galleries, pa...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/f56d8d10-a7fa...   784312
# 1  https://a0.muscache.com/pictures/2085606/7a706...   412283
# 2  https://a0.muscache.com/pictures/2806060/7fc68...  1250232
# 3  https://a0.muscache.com/pictures/2303148/55d1e...   784312
# 4  https://a0.muscache.com/pictures/2881091/f5404...  1432722
#
#                                     host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/784312        Li  2011-07-06
# 1   https://www.airbnb.com/users/show/412283   Fredric  2011-02-27
# 2  https://www.airbnb.com/users/show/1250232       Mia  2011-10-05
# 3   https://www.airbnb.com/users/show/784312        Li  2011-07-06
# 4  https://www.airbnb.com/users/show/1432722   Rodrigo  2011-11-22
#
#        host_location                                         host_about  \
# 0  Stockholm, Sweden  I am a recently retired lady, who has two room...
# 1  Stockholm, Sweden  I am into arts yoga meditation design life rel...
# 2  Stockholm, Sweden  I am from Stockholm. I'm passionate about trav...
# 3  Stockholm, Sweden  I am a recently retired lady, who has two room...
# 4  Stockholm, Sweden  I am from Chile and I have been in Sweden sinc...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0      within an hour               100%                 100%
# 1        within a day               100%                  15%
# 2  within a few hours               100%                   0%
# 3      within an hour               100%                 100%
# 4  within a few hours               100%                 100%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 t  https://a0.muscache.com/im/users/784312/profil...
# 1                 f  https://a0.muscache.com/im/pictures/user/e0c05...
# 2                 f  https://a0.muscache.com/im/users/1250232/profi...
# 3                 t  https://a0.muscache.com/im/users/784312/profil...
# 4                 f  https://a0.muscache.com/im/users/1432722/profi...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/784312/profil...          Södermalm
# 1  https://a0.muscache.com/im/pictures/user/e0c05...        Kungsholmen
# 2  https://a0.muscache.com/im/users/1250232/profi...           Norrmalm
# 3  https://a0.muscache.com/im/users/784312/profil...          Södermalm
# 4  https://a0.muscache.com/im/users/1432722/profi...          Södermalm
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          2
# 1                    2                          4
# 2                    1                          1
# 3                    2                          2
# 4                    3                          3
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3                ['email', 'phone']                    t
# 4  ['email', 'phone', 'work_email']                    t
#
#   host_identity_verified                        neighbourhood  \
# 0                      t                                  NaN
# 1                      t  Stockholm, Stockholm County, Sweden
# 2                      t  Stockholm, Stockholm County, Sweden
# 3                      t                                  NaN
# 4                      t                                  NaN
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0             Södermalms                           NaN    59.314     18.061
# 1           Kungsholmens                           NaN    59.334     18.037
# 2              Norrmalms                           NaN    59.339     18.051
# 3             Södermalms                           NaN    59.312     18.061
# 4             Södermalms                           NaN    59.305     18.108
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0  Private room in rental unit     Private room             2      1.000
# 1  Private room in rental unit     Private room             1      1.000
# 2           Entire rental unit  Entire home/apt             2      1.000
# 3  Private room in rental unit     Private room             1      1.000
# 4           Entire rental unit  Entire home/apt             4      2.000
#
#   bathrooms_text  bedrooms  beds  \
# 0  1 shared bath     1.000 2.000
# 1  1 shared bath     1.000 1.000
# 2         1 bath     1.000 2.000
# 3  1 shared bath     1.000 1.000
# 4        2 baths     3.000 3.000
#
#                                            amenities      price  \
# 0  ["Hair dryer", "Hangers", "Long term stays all...    $944.00
# 1  ["Hangers", "Apple  sound system with aux", "P...    $414.00
# 2  ["Washer", "Hair dryer", "Hangers", "Long term...  $1,320.00
# 3  ["Hair dryer", "Hangers", "Fast wifi \u2013 28...    $814.00
# 4  ["Washer", "TV with standard cable", "Dedicate...  $2,750.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               2             120                       2
# 1               2              20                       2
# 2               1              60                       1
# 3               2             300                       2
# 4               6              30                       6
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       2                     120                     120
# 1                       2                      20                      20
# 2                       1                      60                      60
# 3                       2                     300                     300
# 4                       6                      30                      30
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                   2.000                 120.000               NaN
# 1                   2.000                  20.000               NaN
# 2                   1.000                  60.000               NaN
# 3                   2.000                 300.000               NaN
# 4                   6.000                  30.000               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               27               57               87
# 1                t               25               55               85
# 2                t               28               58               88
# 3                t               30               60               90
# 4                t                2                2                2
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               177            2024-12-30                430
# 1               360            2024-12-30                 64
# 2                88            2024-12-30                110
# 3               180            2024-12-30                414
# 4                 9            2024-12-30                  4
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                     30                       1   2011-07-30  2024-12-09
# 1                      1                       0   2011-09-29  2024-08-30
# 2                      0                       0   2011-11-28  2016-12-13
# 3                     24                       1   2012-02-13  2024-12-01
# 4                      0                       0   2012-07-19  2017-07-31
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                 4.860                   4.870                      4.790
# 1                 4.680                   4.700                      4.630
# 2                 4.790                   4.650                      4.710
# 3                 4.900                   4.880                      4.840
# 4                 5.000                   5.000                      5.000
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                  4.950                        4.970                   4.840
# 1                  4.870                        4.880                   4.810
# 2                  4.850                        4.950                   4.850
# 3                  4.960                        4.980                   4.890
# 4                  5.000                        4.750                   5.000
#
#    review_scores_value  license instant_bookable  \
# 0                4.760      NaN                f
# 1                4.700      NaN                f
# 2                4.640      NaN                f
# 3                4.840      NaN                f
# 4                5.000      NaN                f
#
#    calculated_host_listings_count  \
# 0                               2
# 1                               2
# 2                               1
# 3                               2
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             2
# 1                                             1
# 2                                             0
# 3                                             2
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0              2.630
# 1                                            0              0.400
# 2                                            0              0.690
# 3                                            0              2.640
# 4                                            0              0.030
# 2. DataFrame Info (Column Types and Non-Null Counts):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5223 entries, 0 to 5222
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            5223 non-null   int64
#  1   listing_url                                   5223 non-null   object
#  2   scrape_id                                     5223 non-null   int64
#  3   last_scraped                                  5223 non-null   object
#  4   source                                        5223 non-null   object
#  5   name                                          5223 non-null   object
#  6   description                                   5006 non-null   object
#  7   neighborhood_overview                         1901 non-null   object
#  8   picture_url                                   5223 non-null   object
#  9   host_id                                       5223 non-null   int64
#  10  host_url                                      5223 non-null   object
#  11  host_name                                     5223 non-null   object
#  12  host_since                                    5223 non-null   object
#  13  host_location                                 4269 non-null   object
#  14  host_about                                    2276 non-null   object
#  15  host_response_time                            3071 non-null   object
#  16  host_response_rate                            3071 non-null   object
#  17  host_acceptance_rate                          4147 non-null   object
#  18  host_is_superhost                             5199 non-null   object
#  19  host_thumbnail_url                            5223 non-null   object
#  20  host_picture_url                              5223 non-null   object
#  21  host_neighbourhood                            1485 non-null   object
#  22  host_listings_count                           5223 non-null   int64
#  23  host_total_listings_count                     5223 non-null   int64
#  24  host_verifications                            5223 non-null   object
#  25  host_has_profile_pic                          5223 non-null   object
#  26  host_identity_verified                        5223 non-null   object
#  27  neighbourhood                                 1901 non-null   object
#  28  neighbourhood_cleansed                        5223 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      5223 non-null   float64
#  31  longitude                                     5223 non-null   float64
#  32  property_type                                 5223 non-null   object
#  33  room_type                                     5223 non-null   object
#  34  accommodates                                  5223 non-null   int64
#  35  bathrooms                                     3496 non-null   float64
#  36  bathrooms_text                                5214 non-null   object
#  37  bedrooms                                      4914 non-null   float64
#  38  beds                                          3495 non-null   float64
#  39  amenities                                     5223 non-null   object
#  40  price                                         3498 non-null   object
#  41  minimum_nights                                5223 non-null   int64
#  42  maximum_nights                                5223 non-null   int64
#  43  minimum_minimum_nights                        5223 non-null   int64
#  44  maximum_minimum_nights                        5223 non-null   int64
#  45  minimum_maximum_nights                        5223 non-null   int64
#  46  maximum_maximum_nights                        5223 non-null   int64
#  47  minimum_nights_avg_ntm                        5223 non-null   float64
#  48  maximum_nights_avg_ntm                        5223 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              5027 non-null   object
#  51  availability_30                               5223 non-null   int64
#  52  availability_60                               5223 non-null   int64
#  53  availability_90                               5223 non-null   int64
#  54  availability_365                              5223 non-null   int64
#  55  calendar_last_scraped                         5223 non-null   object
#  56  number_of_reviews                             5223 non-null   int64
#  57  number_of_reviews_ltm                         5223 non-null   int64
#  58  number_of_reviews_l30d                        5223 non-null   int64
#  59  first_review                                  4160 non-null   object
#  60  last_review                                   4160 non-null   object
#  61  review_scores_rating                          4160 non-null   float64
#  62  review_scores_accuracy                        4160 non-null   float64
#  63  review_scores_cleanliness                     4160 non-null   float64
#  64  review_scores_checkin                         4160 non-null   float64
#  65  review_scores_communication                   4160 non-null   float64
#  66  review_scores_location                        4160 non-null   float64
#  67  review_scores_value                           4160 non-null   float64
#  68  license                                       0 non-null      float64
#  69  instant_bookable                              5223 non-null   object
#  70  calculated_host_listings_count                5223 non-null   int64
#  71  calculated_host_listings_count_entire_homes   5223 non-null   int64
#  72  calculated_host_listings_count_private_rooms  5223 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   5223 non-null   int64
#  74  reviews_per_month                             4160 non-null   float64
# dtypes: float64(18), int64(23), object(34)
# memory usage: 3.0+ MB
#
# 3. Descriptive Statistics for Numerical Columns:
#                            id          scrape_id       host_id  \
# count                5223.000           5223.000      5223.000
# mean   615271881759993984.000 20241230011645.000 182750157.987
# std    515664380057263488.000              1.723 192404576.228
# min                164448.000 20241230011645.000      4457.000
# 25%              35777829.000 20241230011645.000  23243281.500
# 50%    801168019967339520.000 20241230011645.000  91345583.000
# 75%   1110622784882269440.000 20241230011645.000 325885492.000
# max   1321949733901820416.000 20241230011645.000 669352745.000
#
#        host_listings_count  host_total_listings_count  \
# count             5223.000                   5223.000
# mean                 9.875                     18.960
# std                 90.592                    249.012
# min                  1.000                      1.000
# 25%                  1.000                      1.000
# 50%                  1.000                      2.000
# 75%                  2.000                      3.000
# max               3284.000                   8065.000
#
#        neighbourhood_group_cleansed  latitude  longitude  accommodates  \
# count                         0.000  5223.000   5223.000      5223.000
# mean                            NaN    59.318     18.031         3.452
# std                             NaN     0.031      0.065         1.946
# min                             NaN    59.232     17.773         1.000
# 25%                             NaN    59.298     18.001         2.000
# 50%                             NaN    59.317     18.046         3.000
# 75%                             NaN    59.338     18.076         4.000
# max                             NaN    59.419     18.188        16.000
#
#        bathrooms  bedrooms     beds  minimum_nights  maximum_nights  \
# count   3496.000  4914.000 3495.000        5223.000        5223.000
# mean       1.270     1.703    2.120           7.336         331.362
# std        0.625     1.171    1.745          26.294         378.695
# min        0.000     0.000    0.000           1.000           1.000
# 25%        1.000     1.000    1.000           1.000          30.000
# 50%        1.000     1.000    2.000           3.000         300.000
# 75%        1.500     2.000    3.000           5.000         365.000
# max       12.000    12.000   26.000         500.000        1125.000
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# count                5223.000                5223.000                5223.000
# mean                    6.856                   7.847                 421.209
# std                    25.314                  26.817                 435.793
# min                     1.000                   1.000                   1.000
# 25%                     1.000                   2.000                  30.000
# 50%                     2.000                   3.000                 365.000
# 75%                     4.000                   5.000                 999.000
# max                   500.000                 500.000                1125.000
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# count                5223.000                5223.000                5223.000
# mean                  442.352                   7.539                 431.956
# std                   516.378                  26.379                 437.043
# min                     1.000                   1.000                   1.000
# 25%                    30.000                   2.000                  30.000
# 50%                   365.000                   3.000                 365.000
# 75%                  1125.000                   5.000                1039.300
# max                 20000.000                 500.000                3051.000
#
#        calendar_updated  availability_30  availability_60  availability_90  \
# count             0.000         5223.000         5223.000         5223.000
# mean                NaN           11.742           25.071           38.839
# std                 NaN           12.347           25.238           38.116
# min                 NaN            0.000            0.000            0.000
# 25%                 NaN            0.000            0.000            0.000
# 50%                 NaN            6.000           16.000           29.000
# 75%                 NaN           26.000           55.000           83.000
# max                 NaN           30.000           60.000           90.000
#
#        availability_365  number_of_reviews  number_of_reviews_ltm  \
# count          5223.000           5223.000               5223.000
# mean            135.412             27.752                  8.415
# std             135.456             65.706                 21.831
# min               0.000              0.000                  0.000
# 25%               0.000              1.000                  0.000
# 50%              88.000              6.000                  2.000
# 75%             268.000             22.000                  7.000
# max             365.000           1174.000                711.000
#
#        number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# count                5223.000              4160.000                4160.000
# mean                    0.491                 4.808                   4.812
# std                     1.544                 0.359                   0.356
# min                     0.000                 1.000                   1.000
# 25%                     0.000                 4.750                   4.760
# 50%                     0.000                 4.920                   4.920
# 75%                     0.000                 5.000                   5.000
# max                    54.000                 5.000                   5.000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                   4160.000               4160.000
# mean                       4.748                  4.860
# std                        0.405                  0.329
# min                        1.000                  1.000
# 25%                        4.670                  4.850
# 50%                        4.870                  4.960
# 75%                        5.000                  5.000
# max                        5.000                  5.000
#
#        review_scores_communication  review_scores_location  \
# count                     4160.000                4160.000
# mean                         4.870                   4.814
# std                          0.326                   0.307
# min                          1.000                   1.000
# 25%                          4.860                   4.750
# 50%                          5.000                   4.910
# 75%                          5.000                   5.000
# max                          5.000                   5.000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count             4160.000    0.000                        5223.000
# mean                 4.727      NaN                           4.629
# std                  0.383      NaN                          11.033
# min                  1.000      NaN                           1.000
# 25%                  4.650      NaN                           1.000
# 50%                  4.810      NaN                           1.000
# 75%                  5.000      NaN                           2.000
# max                  5.000      NaN                          69.000
#
#        calculated_host_listings_count_entire_homes  \
# count                                     5223.000
# mean                                         4.149
# std                                         11.049
# min                                          0.000
# 25%                                          1.000
# 50%                                          1.000
# 75%                                          1.000
# max                                         69.000
#
#        calculated_host_listings_count_private_rooms  \
# count                                      5223.000
# mean                                          0.451
# std                                           1.699
# min                                           0.000
# 25%                                           0.000
# 50%                                           0.000
# 75%                                           0.000
# max                                          21.000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                     5223.000           4160.000
# mean                                         0.008              1.142
# std                                          0.132              2.286
# min                                          0.000              0.010
# 25%                                          0.000              0.180
# 50%                                          0.000              0.450
# 75%                                          0.000              1.220
# max                                          3.000             76.450
# 4. Descriptive Statistics for Object/Categorical Columns:
#                                 listing_url last_scraped       source  \
# count                                  5223         5223         5223
# unique                                 5223            1            2
# top     https://www.airbnb.com/rooms/164448   2024-12-30  city scrape
# freq                                      1         5223         3498
#
#                       name                                        description  \
# count                 5223                                               5006
# unique                5068                                               4723
# top     Lägenhet Stockholm  Live the simple life in this peaceful and cent...
# freq                    23                                                 23
#
#                                     neighborhood_overview  \
# count                                                1901
# unique                                               1672
# top     The apartment Is located in the heart of Stock...
# freq                                                   34
#
#                                               picture_url  \
# count                                                5223
# unique                                               5170
# top     https://a0.muscache.com/pictures/miso/Hosting-...
# freq                                                    6
#
#                                            host_url host_name  host_since  \
# count                                          5223      5223        5223
# unique                                         4172      1672        2592
# top     https://www.airbnb.com/users/show/271346174      Anna  2019-06-25
# freq                                             69        97          69
#
#             host_location                                         host_about  \
# count                4269                                               2276
# unique                123                                               1623
# top     Stockholm, Sweden  Born and raised in Stockholm and work as a pro...
# freq                 3923                                                 49
#
#        host_response_time host_response_rate host_acceptance_rate  \
# count                3071               3071                 4147
# unique                  4                 47                  101
# top        within an hour               100%                 100%
# freq                 1686               2193                 1058
#
#        host_is_superhost                                 host_thumbnail_url  \
# count               5199                                               5223
# unique                 2                                               3968
# top                    f  https://a0.muscache.com/defaults/user_pic-50x5...
# freq                4263                                                217
#
#                                          host_picture_url host_neighbourhood  \
# count                                                5223               1485
# unique                                               3968                 24
# top     https://a0.muscache.com/defaults/user_pic-225x...          Södermalm
# freq                                                  217                549
#
#         host_verifications host_has_profile_pic host_identity_verified  \
# count                 5223                 5223                   5223
# unique                   5                    2                      2
# top     ['email', 'phone']                    t                      t
# freq                  3989                 5006                   4612
#
#                             neighbourhood neighbourhood_cleansed  \
# count                                1901                   5223
# unique                                 87                     14
# top     Stockholm, Stockholms län, Sweden             Södermalms
# freq                                  406                   1317
#
#              property_type        room_type bathrooms_text  \
# count                 5223             5223           5214
# unique                  43                4             26
# top     Entire rental unit  Entire home/apt         1 bath
# freq                  2947             4316           3048
#
#                                                 amenities      price  \
# count                                                5223       3498
# unique                                               4920       1271
# top     ["Washer", "TV", "Kitchen", "Wifi", "Smoke ala...  $2,500.00
# freq                                                   28         91
#
#        has_availability calendar_last_scraped first_review last_review  \
# count              5027                  5223         4160        4160
# unique                2                     1         1848         883
# top                   t            2024-12-30   2024-05-19  2024-12-15
# freq               5022                  5223           72         114
#
#        instant_bookable
# count              5223
# unique                2
# top                   f
# freq               4512
# 5. Percentage of Missing Values per Column (sorted):
# neighbourhood_group_cleansed   100.000
# license                        100.000
# calendar_updated               100.000
# host_neighbourhood              71.568
# neighborhood_overview           63.603
# neighbourhood                   63.603
# host_about                      56.424
# host_response_rate              41.202
# host_response_time              41.202
# beds                            33.084
# bathrooms                       33.065
# price                           33.027
# host_acceptance_rate            20.601
# reviews_per_month               20.352
# last_review                     20.352
# review_scores_rating            20.352
# review_scores_accuracy          20.352
# review_scores_cleanliness       20.352
# review_scores_checkin           20.352
# review_scores_communication     20.352
# review_scores_location          20.352
# review_scores_value             20.352
# first_review                    20.352
# host_location                   18.265
# bedrooms                         5.916
# description                      4.155
# has_availability                 3.753
# host_is_superhost                0.460
# bathrooms_text                   0.172
# dtype: float64
#
# 6. Number of Unique Values per Column:
# license                                            0
# calendar_updated                                   0
# neighbourhood_group_cleansed                       0
# scrape_id                                          1
# last_scraped                                       1
# calendar_last_scraped                              1
# host_has_profile_pic                               2
# has_availability                                   2
# host_identity_verified                             2
# host_is_superhost                                  2
# instant_bookable                                   2
# source                                             2
# calculated_host_listings_count_shared_rooms        3
# room_type                                          4
# host_response_time                                 4
# host_verifications                                 5
# bedrooms                                           9
# calculated_host_listings_count_private_rooms      11
# bathrooms                                         13
# accommodates                                      14
# neighbourhood_cleansed                            14
# beds                                              16
# number_of_reviews_l30d                            19
# host_neighbourhood                                24
# calculated_host_listings_count_entire_homes       25
# calculated_host_listings_count                    26
# bathrooms_text                                    26
# availability_30                                   31
# host_listings_count                               40
# property_type                                     43
# host_response_rate                                47
# host_total_listings_count                         49
# minimum_minimum_nights                            60
# availability_60                                   61
# minimum_nights                                    62
# maximum_minimum_nights                            65
# neighbourhood                                     87
# review_scores_checkin                             89
# availability_90                                   91
# review_scores_communication                       95
# review_scores_location                            97
# host_acceptance_rate                             101
# review_scores_accuracy                           104
# review_scores_rating                             106
# review_scores_value                              109
# number_of_reviews_ltm                            112
# host_location                                    123
# review_scores_cleanliness                        124
# minimum_maximum_nights                           141
# maximum_maximum_nights                           151
# minimum_nights_avg_ntm                           175
# maximum_nights                                   204
# maximum_nights_avg_ntm                           208
# number_of_reviews                                305
# availability_365                                 364
# reviews_per_month                                555
# last_review                                      883
# price                                           1271
# host_about                                      1623
# host_name                                       1672
# neighborhood_overview                           1672
# first_review                                    1848
# host_since                                      2592
# host_picture_url                                3968
# host_thumbnail_url                              3968
# host_url                                        4172
# host_id                                         4172
# latitude                                        4617
# description                                     4723
# longitude                                       4823
# amenities                                       4920
# name                                            5068
# picture_url                                     5170
# listing_url                                     5223
# id                                              5223
# dtype: int64
#
# 7. Initial check on the 'price' column:
#    Data type: object
#    Example values: ['$944.00' '$414.00' '$1,320.00' '$814.00' '$2,750.00' '$1,190.00'
#  '$750.00' '$4,300.00' '$900.00' '$1,400.00']

# %% [markdown]
# ## Data Preprocessing

# %%
import re # Regular expression library for cleaning text data
import ast # For safely evaluating string representations of lists (like amenities)
from datetime import datetime # To handle date calculations

# Make sure 'df' DataFrame exists from the previous steps
if 'df' not in locals():
    print("Error: DataFrame 'df' not found. Please run the data loading step first.")
else:
    print(f"Starting cleaning process on DataFrame with shape: {df.shape}")

    # --- 1. Drop Unnecessary or Redundant Columns ---
    # Based on EDA: 100% missing, IDs, URLs, free text (for now), metadata, redundant cols

    columns_to_drop = [
        # 100% Missing
        'neighbourhood_group_cleansed', 'license', 'calendar_updated',
        # IDs / URLs / Metadata
        'listing_url', 'scrape_id', 'last_scraped', 'source', 'picture_url',
        'host_id', 'host_url', 'host_name', 'host_thumbnail_url', 'host_picture_url',
        'calendar_last_scraped',
        # Free text (can revisit later for NLP if needed)
        'description', 'neighborhood_overview', 'host_about', 'name',
        # Redundant / High Missing % / Less Useful Location info
        'neighbourhood', # Using neighbourhood_cleansed
        'host_neighbourhood', # Very high missing %
        # Redundant host counts (keeping host_total_listings_count and calculated_host_listings_count)
        'host_listings_count',
        'calculated_host_listings_count_entire_homes',
        'calculated_host_listings_count_private_rooms',
        'calculated_host_listings_count_shared_rooms',
        # Redundant nights variables (keeping minimum_nights, maximum_nights)
        'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
        'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
        # Redundant review counts (keeping number_of_reviews, reviews_per_month)
        'number_of_reviews_ltm', 'number_of_reviews_l30d',
        # Redundant/Less useful bathrooms col (will parse bathrooms_text)
        'bathrooms'
    ]

    # Drop the columns, using errors='ignore' in case some columns were already dropped or don't exist
    df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

    print(f"Dropped {len(columns_to_drop)} columns. New shape: {df.shape}")

    # --- 2. Clean Target Variable ('price') ---
    # Convert price from object (string with $ and ,) to float
    # Also drop rows where price is missing, as they cannot be used for training/evaluation

    if 'price' in df.columns:
        # Drop rows where price is NaN *before* attempting conversion
        original_rows = df.shape[0]
        df.dropna(subset=['price'], inplace=True)
        print(f"Dropped {original_rows - df.shape[0]} rows with missing 'price'. New shape: {df.shape}")

        # Clean the price string and convert to float
        try:
            df['price'] = df['price'].astype(str).str.replace(r'[$,]', '', regex=True).astype(float)
            print("Cleaned 'price' column: removed '$', ',', and converted to float.")
            # Display stats for the cleaned price
            print("\nDescriptive statistics for cleaned 'price':")
            display(df['price'].describe())
        except Exception as e:
            print(f"Error cleaning 'price' column: {e}")
    else:
        print("Warning: 'price' column not found, skipping price cleaning.")


    # --- 3. Convert Boolean-like Columns ('t'/'f') to Binary (1/0) ---
    bool_cols = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified',
                 'has_availability', 'instant_bookable']

    for col in bool_cols:
        if col in df.columns:
            # Impute potential NaNs with the mode (most frequent value, likely 'f') before mapping
            mode_val = df[col].mode()[0]
            df[col].fillna(mode_val, inplace=True)
            # Map 't' to 1 and 'f' to 0
            df[col] = np.where(df[col] == 't', 1, 0)
            print(f"Converted '{col}' to binary (1/0).")

    print(f"Converted boolean-like columns {bool_cols} to binary (1/0).")


    # --- 4. Clean and Convert Percentage Columns ---
    # host_response_rate, host_acceptance_rate
    percent_cols = ['host_response_rate', 'host_acceptance_rate']
    for col in percent_cols:
        if col in df.columns:
            # Convert to string, remove '%', convert to float, divide by 100
            df[col] = df[col].astype(str).str.replace('%', '', regex=False).astype(float) / 100.0
            # Missing values will be handled later (imputation)
            print(f"Cleaned and converted '{col}' to float (0-1 scale).") 

    print(f"Cleaned percentage columns {percent_cols} (converted to 0-1 float scale).")


    # --- 5. Convert Date Columns and Engineer Host Duration ---
    date_cols = ['host_since', 'first_review', 'last_review']
    current_time = datetime.now() # Use current time for calculations like host duration

    for col in date_cols:
        if col in df.columns:
            # Convert to datetime objects, coercing errors will turn unparseable dates into NaT (Not a Time)
            df[col] = pd.to_datetime(df[col], errors='coerce')
            print(f"Converted '{col}' to datetime objects.")

    # Engineer host_duration_days
    if 'host_since' in df.columns and pd.api.types.is_datetime64_any_dtype(df['host_since']):
        df['host_duration_days'] = (current_time - df['host_since']).dt.days
        # Handle potential NaT in host_since (which result in NaT in duration) - imputation later
        print("Engineered 'host_duration_days' feature.")
    else:
         print("Could not engineer 'host_duration_days': 'host_since' column missing or not datetime.")

    print(f"Converted date columns {date_cols} to datetime objects.")


    # --- 6. Parse 'bathrooms_text' ---
    # Extract number of baths and type (shared/private)

    if 'bathrooms_text' in df.columns:
        # Fill the few missing values with the mode
        mode_bath_text = df['bathrooms_text'].mode()[0]
        df['bathrooms_text'].fillna(mode_bath_text, inplace=True)
        print(f"Imputed {df['bathrooms_text'].isnull().sum()} missing values in 'bathrooms_text' with mode ('{mode_bath_text}').") # Should be 0 now

        # Extract number of baths (handles floats like 1.5, half-bath as 0.5)
        df['num_bathrooms'] = df['bathrooms_text'].str.extract(r'(\d+\.?\d*)').astype(float)
        # Handle 'Half-bath' specifically if the regex didn't catch it properly or if represented differently
        df['num_bathrooms'] = df['num_bathrooms'].fillna(0.5).where(df['bathrooms_text'].str.contains('Half-bath', case=False, na=False), df['num_bathrooms'])
        # Default to 1 bath if extraction failed and it's not a half-bath (e.g., just 'Private bath')
        df['num_bathrooms'].fillna(1.0, inplace=True)


        # Extract bath type (shared/private) - create a binary flag 'is_shared_bath'
        df['is_shared_bath'] = df['bathrooms_text'].str.contains('shared', case=False, na=False).astype(int)

        print("Parsed 'bathrooms_text': created 'num_bathrooms' (float) and 'is_shared_bath' (binary).")
        # Can drop the original column now
        df.drop(columns=['bathrooms_text'], inplace=True, errors='ignore')

    else:
        print("Warning: 'bathrooms_text' column not found, skipping parsing.")


    # --- 7. Parse 'amenities' ---
    # Convert string representation of list into actual list, then count amenities

    if 'amenities' in df.columns:
        # Function to safely parse the string representation of a list
        def parse_stringified_list(s):
            try:
                # Handle empty lists "[]" or potential variations
                if isinstance(s, str) and s.strip() and s.strip() != '[]':
                    # ast.literal_eval is safer than eval()
                    parsed_list = ast.literal_eval(s)
                    return parsed_list if isinstance(parsed_list, list) else []
                else:
                    return []
            except (ValueError, SyntaxError):
                # Return empty list if parsing fails
                return []

        df['amenities_list'] = df['amenities'].apply(parse_stringified_list)
        df['num_amenities'] = df['amenities_list'].apply(len)

        print("Parsed 'amenities': created 'amenities_list' and 'num_amenities'.")
        # Keep 'amenities_list' for potential multi-hot encoding later
        # Drop the original raw 'amenities' string column
        df.drop(columns=['amenities'], inplace=True, errors='ignore')
    else:
        print("Warning: 'amenities' column not found, skipping parsing.")


    # --- 8. Parse 'host_verifications' ---
    if 'host_verifications' in df.columns:
        # Use the same parsing function as for amenities
        df['verifications_list'] = df['host_verifications'].apply(parse_stringified_list)
        df['num_host_verifications'] = df['verifications_list'].apply(len)

        print("Parsed 'host_verifications': created 'verifications_list' and 'num_host_verifications'.")
        # Keep 'verifications_list' for potential feature engineering if needed
        # Drop the original raw 'host_verifications' string column
        df.drop(columns=['host_verifications'], inplace=True, errors='ignore')
    else:
         print("Warning: 'host_verifications' column not found, skipping parsing.")


    # --- 9. Handle Remaining Missing Values (Imputation) ---
    print("\n--- Handling Remaining Missing Values ---")

    # Strategy:
    # - Numerical: Impute with median (robust to outliers) or 0 where it makes sense (reviews).
    # - Categorical: Impute with a specific category like 'Unknown'.
    # - Datetime: Leave as NaT for now, or impute derived features (like duration).

    # Numerical Imputation
    num_cols_to_impute = {
        'host_response_rate': df['host_response_rate'].median(),
        'host_acceptance_rate': df['host_acceptance_rate'].median(),
        'bedrooms': df['bedrooms'].median(),
        'beds': df['beds'].median(), # High missing %, median is a simple start
        'host_duration_days': df['host_duration_days'].median(), # If host_since was missing
        # Review-related columns: Impute with 0 where number_of_reviews is 0
        'review_scores_rating': 0, 'review_scores_accuracy': 0, 'review_scores_cleanliness': 0,
        'review_scores_checkin': 0, 'review_scores_communication': 0, 'review_scores_location': 0,
        'review_scores_value': 0, 'reviews_per_month': 0
    }

    for col, fill_value in num_cols_to_impute.items():
        if col in df.columns:
            original_nan_count = df[col].isnull().sum()
            if original_nan_count > 0:
                # Special handling for review scores/reviews per month: only impute if number_of_reviews > 0?
                # Simpler approach: Impute all NaNs first. If col is reviews_per_month or review_scores*, impute with 0.
                if col.startswith('review_scores_') or col == 'reviews_per_month':
                     df[col].fillna(0, inplace=True)
                     print(f"Imputed {original_nan_count} missing values in '{col}' with 0.")
                else:
                    df[col].fillna(fill_value, inplace=True)
                    print(f"Imputed {original_nan_count} missing values in '{col}' with median ({fill_value:.3f}).")

    # Categorical Imputation
    cat_cols_to_impute = {
        'host_response_time': 'Unknown', # Create a new category
        'host_location': 'Unknown'     # Create a new category
    }
    for col, fill_value in cat_cols_to_impute.items():
         if col in df.columns:
            original_nan_count = df[col].isnull().sum()
            if original_nan_count > 0:
                df[col].fillna(fill_value, inplace=True)
                print(f"Imputed {original_nan_count} missing values in '{col}' with '{fill_value}'.")

    
    # --- 10. Final Check ---
    print("\n--- Final Check after Cleaning and Preprocessing ---")

    print("\n1. Remaining Missing Values per Column:")
    final_missing = df.isnull().sum()
    final_missing = final_missing[final_missing > 0]
    if not final_missing.empty:
        print(final_missing)
    else:
        print("No remaining missing values found (excluding potential NaTs in datetime columns).")

    print("\n2. DataFrame Info after Cleaning:")
    buffer = io.StringIO()
    df.info(buf=buffer, verbose=True)
    info_str = buffer.getvalue()
    print(info_str)

    print("\n3. First 5 rows of the cleaned DataFrame:")
    display(df.head())

    print("\nData cleaning and preprocessing step completed.")
# Out:
# Starting cleaning process on DataFrame with shape: (3498, 46)
# Dropped 33 columns. New shape: (3498, 46)
# Dropped 0 rows with missing 'price'. New shape: (3498, 46)
# Cleaned 'price' column: removed '$', ',', and converted to float.
#
# Descriptive statistics for cleaned 'price':
# count     3498.000
# mean      2140.879
# std      10108.348
# min        105.000
# 25%        838.250
# 50%       1300.000
# 75%       2181.000
# max     500000.000
# Name: price, dtype: float64
# Converted 'host_is_superhost' to binary (1/0).
# Converted 'host_has_profile_pic' to binary (1/0).
# Converted 'host_identity_verified' to binary (1/0).
# Converted 'has_availability' to binary (1/0).
# Converted 'instant_bookable' to binary (1/0).
# Converted boolean-like columns ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'has_availability', 'instant_bookable'] to binary (1/0).
# Cleaned and converted 'host_response_rate' to float (0-1 scale).
# Cleaned and converted 'host_acceptance_rate' to float (0-1 scale).
# Cleaned percentage columns ['host_response_rate', 'host_acceptance_rate'] (converted to 0-1 float scale).
# Converted 'host_since' to datetime objects.
# Converted 'first_review' to datetime objects.
# Converted 'last_review' to datetime objects.
# Engineered 'host_duration_days' feature.
# Converted date columns ['host_since', 'first_review', 'last_review'] to datetime objects.
# Warning: 'bathrooms_text' column not found, skipping parsing.
# Warning: 'amenities' column not found, skipping parsing.
# Warning: 'host_verifications' column not found, skipping parsing.
#
# --- Handling Remaining Missing Values ---
#
# --- Final Check after Cleaning and Preprocessing ---
#
# 1. Remaining Missing Values per Column:
# first_review    722
# last_review     722
# dtype: int64
#
# 2. DataFrame Info after Cleaning:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3498 entries, 0 to 5222
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3498 non-null   int64
#  1   host_since                      3498 non-null   datetime64[ns]
#  2   host_location                   3498 non-null   object
#  3   host_response_time              3498 non-null   object
#  4   host_response_rate              3498 non-null   float64
#  5   host_acceptance_rate            3498 non-null   float64
#  6   host_is_superhost               3498 non-null   int32
#  7   host_total_listings_count       3498 non-null   int64
#  8   host_has_profile_pic            3498 non-null   int32
#  9   host_identity_verified          3498 non-null   int32
#  10  neighbourhood_cleansed          3498 non-null   object
#  11  latitude                        3498 non-null   float64
#  12  longitude                       3498 non-null   float64
#  13  property_type                   3498 non-null   object
#  14  room_type                       3498 non-null   object
#  15  accommodates                    3498 non-null   int64
#  16  bedrooms                        3498 non-null   float64
#  17  beds                            3498 non-null   float64
#  18  price                           3498 non-null   float64
#  19  minimum_nights                  3498 non-null   int64
#  20  maximum_nights                  3498 non-null   int64
#  21  has_availability                3498 non-null   int32
#  22  availability_30                 3498 non-null   int64
#  23  availability_60                 3498 non-null   int64
#  24  availability_90                 3498 non-null   int64
#  25  availability_365                3498 non-null   int64
#  26  number_of_reviews               3498 non-null   int64
#  27  first_review                    2776 non-null   datetime64[ns]
#  28  last_review                     2776 non-null   datetime64[ns]
#  29  review_scores_rating            3498 non-null   float64
#  30  review_scores_accuracy          3498 non-null   float64
#  31  review_scores_cleanliness       3498 non-null   float64
#  32  review_scores_checkin           3498 non-null   float64
#  33  review_scores_communication     3498 non-null   float64
#  34  review_scores_location          3498 non-null   float64
#  35  review_scores_value             3498 non-null   float64
#  36  instant_bookable                3498 non-null   int32
#  37  calculated_host_listings_count  3498 non-null   int64
#  38  reviews_per_month               3498 non-null   float64
#  39  host_duration_days              3498 non-null   int64
#  40  num_bathrooms                   3498 non-null   float64
#  41  is_shared_bath                  3498 non-null   int32
#  42  amenities_list                  3498 non-null   object
#  43  num_amenities                   3498 non-null   int64
#  44  verifications_list              3498 non-null   object
#  45  num_host_verifications          3498 non-null   int64
# dtypes: datetime64[ns](3), float64(16), int32(6), int64(14), object(7)
# memory usage: 1.2+ MB
#
#
# 3. First 5 rows of the cleaned DataFrame:
#        id host_since      host_location  host_response_time  \
# 0  164448 2011-07-06  Stockholm, Sweden      within an hour
# 1  220851 2011-02-27  Stockholm, Sweden        within a day
# 2  238411 2011-10-05  Stockholm, Sweden  within a few hours
# 3  242188 2011-07-06  Stockholm, Sweden      within an hour
# 4  273906 2011-11-22  Stockholm, Sweden  within a few hours
#
#    host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0               0.010                 0.010                  0
# 1               0.010                 0.002                  0
# 2               0.010                 0.000                  0
# 3               0.010                 0.010                  0
# 4               0.010                 0.010                  0
#
#    host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 0                          2                     0                       0
# 1                          4                     0                       0
# 2                          1                     0                       0
# 3                          2                     0                       0
# 4                          3                     0                       0
#
#   neighbourhood_cleansed  latitude  longitude                property_type  \
# 0             Södermalms    59.314     18.061  Private room in rental unit
# 1           Kungsholmens    59.334     18.037  Private room in rental unit
# 2              Norrmalms    59.339     18.051           Entire rental unit
# 3             Södermalms    59.312     18.061  Private room in rental unit
# 4             Södermalms    59.305     18.108           Entire rental unit
#
#          room_type  accommodates  bedrooms  beds    price  minimum_nights  \
# 0     Private room             2     1.000 2.000  944.000               2
# 1     Private room             1     1.000 1.000  414.000               2
# 2  Entire home/apt             2     1.000 2.000 1320.000               1
# 3     Private room             1     1.000 1.000  814.000               2
# 4  Entire home/apt             4     3.000 3.000 2750.000               6
#
#    maximum_nights  has_availability  availability_30  availability_60  \
# 0             120                 0               27               57
# 1              20                 0               25               55
# 2              60                 0               28               58
# 3             300                 0               30               60
# 4              30                 0                2                2
#
#    availability_90  availability_365  number_of_reviews first_review  \
# 0               87               177                430   2011-07-30
# 1               85               360                 64   2011-09-29
# 2               88                88                110   2011-11-28
# 3               90               180                414   2012-02-13
# 4                2                 9                  4   2012-07-19
#
#   last_review  review_scores_rating  review_scores_accuracy  \
# 0  2024-12-09                 4.860                   4.870
# 1  2024-08-30                 4.680                   4.700
# 2  2016-12-13                 4.790                   4.650
# 3  2024-12-01                 4.900                   4.880
# 4  2017-07-31                 5.000                   5.000
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                      4.790                  4.950
# 1                      4.630                  4.870
# 2                      4.710                  4.850
# 3                      4.840                  4.960
# 4                      5.000                  5.000
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                        4.970                   4.840                4.760
# 1                        4.880                   4.810                4.700
# 2                        4.950                   4.850                4.640
# 3                        4.980                   4.890                4.840
# 4                        4.750                   5.000                5.000
#
#    instant_bookable  calculated_host_listings_count  reviews_per_month  \
# 0                 0                               2              2.630
# 1                 0                               2              0.400
# 2                 0                               1              0.690
# 3                 0                               2              2.640
# 4                 0                               2              0.030
#
#    host_duration_days  num_bathrooms  is_shared_bath  \
# 0                5041          1.000               1
# 1                5170          1.000               1
# 2                4950          1.000               0
# 3                5041          1.000               1
# 4                4902          2.000               0
#
#                                       amenities_list  num_amenities  \
# 0  [Hair dryer, Hangers, Long term stays allowed,...             29
# 1  [Hangers, Apple  sound system with aux, Privat...             26
# 2  [Washer, Hair dryer, Hangers, Long term stays ...             29
# 3  [Hair dryer, Hangers, Fast wifi – 283 Mbps, Ho...             27
# 4  [Washer, TV with standard cable, Dedicated wor...              8
#
#            verifications_list  num_host_verifications
# 0              [email, phone]                       2
# 1              [email, phone]                       2
# 2              [email, phone]                       2
# 3              [email, phone]                       2
# 4  [email, phone, work_email]                       3
# Data cleaning and preprocessing step completed.

# %%
# Handling columns that still have null-values

# 1. We create a column to tell if a listing was never reviewd. We can get it from the number of reviews. This might be important
# to determine the price of new listings, and to see how it impacts prices of current listings
df['never_reviewed'] = (df['number_of_reviews'] == 0).astype(int)

reference_date = df['last_review'].max() # last observed revew in the dataset

# Days since last review: could be interesting for the regression to tell ho recent the last visit was to a listing
df['days_since_last_review'] = (reference_date - df['last_review']).dt.days

# Days since first review: it might be important to determine how "historically" this listing was. 
df['days_since_first_review'] = (reference_date - df['first_review']).dt.days

max_last = df['days_since_last_review'].max()
df['days_since_last_review'].fillna(max_last, inplace=True) # if a listing doesn't have any review, we put the max value here
df['days_since_first_review'].fillna(0, inplace=True) # if it was null, we put 0 
# these settings will likely be the same when trying to predict the price of NEW listings

df.drop(columns=['first_review', 'last_review'], inplace=True) # no loonger needed after new columns 

# Now we check again the dataset after these additional operations
print("\nDataFrame Info after (additional) Cleaning and Manipulation:")
buffer = io.StringIO()
df.info(buf=buffer, verbose=True)
info_str = buffer.getvalue()
print(info_str)
# Out:
# DataFrame Info after (additional) Cleaning and Manipulation:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3498 entries, 0 to 5222
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3498 non-null   int64
#  1   host_since                      3498 non-null   datetime64[ns]
#  2   host_location                   3498 non-null   object
#  3   host_response_time              3498 non-null   object
#  4   host_response_rate              3498 non-null   float64
#  5   host_acceptance_rate            3498 non-null   float64
#  6   host_is_superhost               3498 non-null   int32
#  7   host_total_listings_count       3498 non-null   int64
#  8   host_has_profile_pic            3498 non-null   int32
#  9   host_identity_verified          3498 non-null   int32
#  10  neighbourhood_cleansed          3498 non-null   object
#  11  latitude                        3498 non-null   float64
#  12  longitude                       3498 non-null   float64
#  13  property_type                   3498 non-null   object
#  14  room_type                       3498 non-null   object
#  15  accommodates                    3498 non-null   int64
#  16  bedrooms                        3498 non-null   float64
#  17  beds                            3498 non-null   float64
#  18  price                           3498 non-null   float64
#  19  minimum_nights                  3498 non-null   int64
#  20  maximum_nights                  3498 non-null   int64
#  21  has_availability                3498 non-null   int32
#  22  availability_30                 3498 non-null   int64
#  23  availability_60                 3498 non-null   int64
#  24  availability_90                 3498 non-null   int64
#  25  availability_365                3498 non-null   int64
#  26  number_of_reviews               3498 non-null   int64
#  27  review_scores_rating            3498 non-null   float64
#  28  review_scores_accuracy          3498 non-null   float64
#  29  review_scores_cleanliness       3498 non-null   float64
#  30  review_scores_checkin           3498 non-null   float64
#  31  review_scores_communication     3498 non-null   float64
#  32  review_scores_location          3498 non-null   float64
#  33  review_scores_value             3498 non-null   float64
#  34  instant_bookable                3498 non-null   int32
#  35  calculated_host_listings_count  3498 non-null   int64
#  36  reviews_per_month               3498 non-null   float64
#  37  host_duration_days              3498 non-null   int64
#  38  num_bathrooms                   3498 non-null   float64
#  39  is_shared_bath                  3498 non-null   int32
#  40  amenities_list                  3498 non-null   object
#  41  num_amenities                   3498 non-null   int64
#  42  verifications_list              3498 non-null   object
#  43  num_host_verifications          3498 non-null   int64
#  44  never_reviewed                  3498 non-null   int32
#  45  days_since_last_review          3498 non-null   float64
#  46  days_since_first_review         3498 non-null   float64
# dtypes: datetime64[ns](1), float64(18), int32(7), int64(14), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Dataset backup after processing

# %%
# Save processed dataset
df.to_csv('listings_clean.csv', index=False)
print("Dataset saved in 'listings_clean.csv'")
# Out:
# Dataset saved in 'listings_clean.csv'

# %%
import pandas as pd

if 'df' not in globals():            
    try:
        df = pd.read_csv('listings_clean.csv')
        print("Dataset loaded from 'listings_clean.csv'")
    except FileNotFoundError:
        raise FileNotFoundError("File 'listings_clean.csv' not found.")
else:
    print("'df' is already in memory, we are good to go!")
# Out:
# 'df' is already in memory, we are good to go!
